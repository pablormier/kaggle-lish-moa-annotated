# %% [markdown]
# # LISH-Harvard MoA Kaggle dataset annotation
#
# This notebook combines the original Kaggle's LISH-MoA challenge data (https://www.kaggle.com/c/lish-moa) and the annotations provided by LISH-Harvard after the competition (https://github.com/LISHarvard/moa_challenge) into one single, annotated csv, including cell names and gene names

# %%
import pandas as pd

# %%
df_training_ft = pd.read_csv('dataset/kaggle/train_features.csv.zip').set_index('sig_id')
df_test_ft = pd.read_csv('dataset/kaggle/test_features.csv.zip').set_index('sig_id')
df_training_targets = pd.read_csv('dataset/kaggle/train_targets_scored.csv.zip').set_index('sig_id')
df_training_nonscored = pd.read_csv('dataset/kaggle/train_targets_nonscored.csv.zip').set_index('sig_id')
df_ids = pd.read_csv('dataset/kaggle/train_drug.csv.zip').set_index('sig_id')

# %% [markdown]
# Load the true annotations for genes/cells from https://github.com/LISHarvard/moa_challenge

# %%
df_cell_info = pd.read_csv('https://raw.githubusercontent.com/LISHarvard/moa_challenge/master/cell_info.csv')
df_cell_mapping = pd.read_csv('https://raw.githubusercontent.com/LISHarvard/moa_challenge/master/cell_mapping.csv')
df_genes = pd.read_csv('https://raw.githubusercontent.com/LISHarvard/moa_challenge/master/gene_mapping.csv')

# %%
df_cells = df_cell_info.set_index('rid').join(df_cell_mapping.set_index('old'))
df_cells['alias'] = df_cells['new'] + '-' + df_cells['ccle_name']
df_cells
# Out:
#                            ccle_name   new                               alias
# rid
# c-100              MIAPACA2_PANCREAS  c-24              c-24-MIAPACA2_PANCREAS
# c-126  42MGBA_CENTRAL_NERVOUS_SYSTEM  c-25  c-25-42MGBA_CENTRAL_NERVOUS_SYSTEM
# c-127                      A375_SKIN  c-26                      c-26-A375_SKIN
# c-128                 FTC133_THYROID  c-27                 c-27-FTC133_THYROID
# c-129             HT1080_SOFT_TISSUE  c-28             c-28-HT1080_SOFT_TISSUE
# ...                              ...   ...                                 ...
# c-95                     DMS273_LUNG  c-19                    c-19-DMS273_LUNG
# c-96                       G361_SKIN  c-20                      c-20-G361_SKIN
# c-97                     OAW42_OVARY  c-21                    c-21-OAW42_OVARY
# c-98                    HMC18_BREAST  c-22                   c-22-HMC18_BREAST
# c-99                    CAL54_KIDNEY  c-23                   c-23-CAL54_KIDNEY
#
# [104 rows x 3 columns]

# %% [markdown]
# Load gene metadata and symbols mapped with gProfiler

# %%
df_gene_mapping = pd.read_csv('dataset/gProfiler_gene_symbols.csv.zip')
df_gene_mapping['alias'] = 'g-' + df_gene_mapping.name + '_' + df_gene_mapping.initial_alias.astype(str)
df_gene_mapping
# Out:
#      initial_alias converted_alias    name  \
# 0               16           AARS1   AARS1
# 1               23           ABCF1   ABCF1
# 2               25            ABL1    ABL1
# 3               30           ACAA1   ACAA1
# 4               47            ACLY    ACLY
# ..             ...             ...     ...
# 769         116832          RPL39L  RPL39L
# 770         148022          TICAM1  TICAM1
# 771         200734          SPRED2  SPRED2
# 772         256364            EML3    EML3
# 773         388650          DIPK1A  DIPK1A
#
#                                            description       namespace  \
# 0    alanyl-tRNA synthetase 1 [Source:HGNC Symbol;A...  ENTREZGENE_ACC
# 1    ATP binding cassette subfamily F member 1 [Sou...  ENTREZGENE_ACC
# 2    ABL proto-oncogene 1, non-receptor tyrosine ki...  ENTREZGENE_ACC
# 3    acetyl-CoA acyltransferase 1 [Source:HGNC Symb...  ENTREZGENE_ACC
# 4    ATP citrate lyase [Source:HGNC Symbol;Acc:HGNC...  ENTREZGENE_ACC
# ..                                                 ...             ...
# 769  ribosomal protein L39 like [Source:HGNC Symbol...  ENTREZGENE_ACC
# 770  toll like receptor adaptor molecule 1 [Source:...  ENTREZGENE_ACC
# 771  sprouty related EVH1 domain containing 2 [Sour...  ENTREZGENE_ACC
# 772    EMAP like 3 [Source:HGNC Symbol;Acc:HGNC:26666]  ENTREZGENE_ACC
# 773  divergent protein kinase domain 1A [Source:HGN...  ENTREZGENE_ACC
#
#                alias
# 0         g-AARS1_16
# 1         g-ABCF1_23
# 2          g-ABL1_25
# 3         g-ACAA1_30
# 4          g-ACLY_47
# ..               ...
# 769  g-RPL39L_116832
# 770  g-TICAM1_148022
# 771  g-SPRED2_200734
# 772    g-EML3_256364
# 773  g-DIPK1A_388650
#
# [774 rows x 6 columns]

# %%
df_tr = pd.concat([df_training_ft, df_training_targets, df_training_nonscored], axis=1)
df_tr.insert(0, 'training', True)
df_tr
# Out:
#               training      cp_type  cp_time cp_dose     g-0     g-1     g-2  \
# sig_id
# id_000644bb2      True       trt_cp       24      D1  1.0620  0.5577 -0.2479
# id_000779bfc      True       trt_cp       72      D1  0.0743  0.4087  0.2991
# id_000a6266a      True       trt_cp       48      D1  0.6280  0.5817  1.5540
# id_0015fd391      True       trt_cp       48      D1 -0.5138 -0.2491 -0.2656
# id_001626bd3      True       trt_cp       72      D2 -0.3254 -0.4009  0.9700
# ...                ...          ...      ...     ...     ...     ...     ...
# id_fffb1ceed      True       trt_cp       24      D2  0.1394 -0.0636 -0.1112
# id_fffb70c0c      True       trt_cp       24      D2 -1.3260  0.3478 -0.3743
# id_fffc1c3f4      True  ctl_vehicle       48      D2  0.3942  0.3756  0.3109
# id_fffcb9e7c      True       trt_cp       24      D1  0.6660  0.2324  0.4392
# id_ffffdd77b      True       trt_cp       72      D1 -0.8598  1.0240 -0.1361
#
#                  g-3     g-4     g-5  ...  ve-cadherin_antagonist  \
# sig_id                                ...
# id_000644bb2 -0.6208 -0.1944 -1.0120  ...                       0
# id_000779bfc  0.0604  1.0190  0.5207  ...                       0
# id_000a6266a -0.0764 -0.0323  1.2390  ...                       0
# id_0015fd391  0.5288  4.0620 -0.8095  ...                       0
# id_001626bd3  0.6919  1.4180 -0.8244  ...                       0
# ...              ...     ...     ...  ...                     ...
# id_fffb1ceed -0.5080 -0.4713  0.7201  ...                       0
# id_fffb70c0c  0.9905 -0.7178  0.6621  ...                       0
# id_fffc1c3f4 -0.7389  0.5505 -0.0159  ...                       0
# id_fffcb9e7c  0.2044  0.8531 -0.0343  ...                       0
# id_ffffdd77b  0.7952 -0.3611 -3.6750  ...                       0
#
#               vesicular_monoamine_transporter_inhibitor  vitamin_k_antagonist  \
# sig_id
# id_000644bb2                                          0                     0
# id_000779bfc                                          0                     0
# id_000a6266a                                          0                     0
# id_0015fd391                                          0                     0
# id_001626bd3                                          0                     0
# ...                                                 ...                   ...
# id_fffb1ceed                                          0                     0
# id_fffb70c0c                                          0                     0
# id_fffc1c3f4                                          0                     0
# id_fffcb9e7c                                          0                     0
# id_ffffdd77b                                          0                     0
#
#               voltage-gated_calcium_channel_ligand  \
# sig_id
# id_000644bb2                                     0
# id_000779bfc                                     0
# id_000a6266a                                     0
# id_0015fd391                                     0
# id_001626bd3                                     0
# ...                                            ...
# id_fffb1ceed                                     0
# id_fffb70c0c                                     0
# id_fffc1c3f4                                     0
# id_fffcb9e7c                                     0
# id_ffffdd77b                                     0
#
#               voltage-gated_potassium_channel_activator  \
# sig_id
# id_000644bb2                                          0
# id_000779bfc                                          0
# id_000a6266a                                          0
# id_0015fd391                                          0
# id_001626bd3                                          0
# ...                                                 ...
# id_fffb1ceed                                          0
# id_fffb70c0c                                          0
# id_fffc1c3f4                                          0
# id_fffcb9e7c                                          0
# id_ffffdd77b                                          0
#
#               voltage-gated_sodium_channel_blocker  \
# sig_id
# id_000644bb2                                     0
# id_000779bfc                                     0
# id_000a6266a                                     0
# id_0015fd391                                     0
# id_001626bd3                                     0
# ...                                            ...
# id_fffb1ceed                                     0
# id_fffb70c0c                                     0
# id_fffc1c3f4                                     0
# id_fffcb9e7c                                     0
# id_ffffdd77b                                     0
#
#               wdr5_mll_interaction_inhibitor  wnt_agonist  \
# sig_id
# id_000644bb2                               0            0
# id_000779bfc                               0            0
# id_000a6266a                               0            0
# id_0015fd391                               0            0
# id_001626bd3                               0            0
# ...                                      ...          ...
# id_fffb1ceed                               0            0
# id_fffb70c0c                               0            0
# id_fffc1c3f4                               0            0
# id_fffcb9e7c                               0            0
# id_ffffdd77b                               0            0
#
#               xanthine_oxidase_inhibitor  xiap_inhibitor
# sig_id
# id_000644bb2                           0               0
# id_000779bfc                           0               0
# id_000a6266a                           0               0
# id_0015fd391                           0               0
# id_001626bd3                           0               0
# ...                                  ...             ...
# id_fffb1ceed                           0               0
# id_fffb70c0c                           0               0
# id_fffc1c3f4                           0               0
# id_fffcb9e7c                           0               0
# id_ffffdd77b                           0               0
#
# [23814 rows x 1484 columns]

# %%
df_t = df_test_ft.copy()
df_t.insert(0, 'training', False)
df_t
# Out:
#               training      cp_type  cp_time cp_dose     g-0     g-1     g-2  \
# sig_id
# id_0004d9e33     False       trt_cp       24      D1 -0.5458  0.1306 -0.5135
# id_001897cda     False       trt_cp       72      D1 -0.1829  0.2320  1.2080
# id_002429b5b     False  ctl_vehicle       24      D1  0.1852 -0.1404 -0.3911
# id_00276f245     False       trt_cp       24      D2  0.4828  0.1955  0.3825
# id_0027f1083     False       trt_cp       48      D1 -0.3979 -1.2680  1.9130
# ...                ...          ...      ...     ...     ...     ...     ...
# id_ff7004b87     False       trt_cp       24      D1  0.4571 -0.5743  3.3930
# id_ff925dd0d     False       trt_cp       24      D1 -0.5885 -0.2548  2.5850
# id_ffb710450     False       trt_cp       72      D1 -0.3985 -0.1554  0.2677
# id_ffbb869f2     False       trt_cp       48      D2 -1.0960 -1.7750 -0.3977
# id_ffd5800b6     False       trt_cp       72      D1 -0.5174  0.2953  0.3286
#
#                  g-3     g-4     g-5  ...    c-90    c-91    c-92    c-93  \
# sig_id                                ...
# id_0004d9e33  0.4408  1.5500 -0.1644  ...  0.0981  0.7978 -0.1430 -0.2067
# id_001897cda -0.4522 -0.3652 -0.3319  ... -0.1190 -0.1852 -1.0310 -1.3670
# id_002429b5b  0.1310 -1.4380  0.2455  ... -0.2261  0.3370 -1.3840  0.8604
# id_00276f245  0.4244 -0.5855 -1.2020  ...  0.1260  0.1570 -0.1784 -1.1200
# id_0027f1083  0.2057 -0.5864 -0.0166  ...  0.4965  0.7578 -0.1580  1.0510
# ...              ...     ...     ...  ...     ...     ...     ...     ...
# id_ff7004b87 -0.6202  0.8557  1.6240  ... -1.1790 -0.6422 -0.4367  0.0159
# id_ff925dd0d  0.3456  0.4401  0.3107  ...  0.0210  0.5780 -0.5888  0.8057
# id_ffb710450 -0.6813  0.0152  0.4791  ...  0.4418  0.9153 -0.1862  0.4049
# id_ffbb869f2  1.0160 -1.3350 -0.2207  ...  0.3079 -0.4473 -0.8192  0.7785
# id_ffd5800b6 -0.0428 -0.0800  0.8702  ...  0.0363  0.1708  0.5939 -0.0507
#
#                 c-94    c-95    c-96    c-97    c-98    c-99
# sig_id
# id_0004d9e33 -0.2303 -0.1193  0.0210 -0.0502  0.1510 -0.7750
# id_001897cda -0.3690 -0.5382  0.0359 -0.4764 -1.3810 -0.7300
# id_002429b5b -1.9530 -1.0140  0.8662  1.0160  0.4924 -0.1942
# id_00276f245 -0.4325 -0.9005  0.8131 -0.1305  0.5645 -0.5809
# id_0027f1083  0.5742  1.0900 -0.2962 -0.5313  0.9931  1.8380
# ...              ...     ...     ...     ...     ...     ...
# id_ff7004b87 -0.6539 -0.4791 -1.2680 -1.1280 -0.4167 -0.6600
# id_ff925dd0d  0.9312  1.2730  0.2614 -0.2790 -0.0131 -0.0934
# id_ffb710450  0.9568  0.4666  0.0461  0.5888 -0.4205 -0.1504
# id_ffbb869f2  0.3133  0.1286 -0.2618  0.5074  0.7430 -0.0484
# id_ffd5800b6  0.2811 -0.4041 -0.4948  0.0757 -0.1356  0.5280
#
# [3982 rows x 876 columns]

# %%
df_dataset = pd.concat([df_tr, df_t], axis=0).join(df_ids)
df_dataset
# Out:
#               training cp_type  cp_time cp_dose     g-0     g-1     g-2  \
# sig_id
# id_000644bb2      True  trt_cp       24      D1  1.0620  0.5577 -0.2479
# id_000779bfc      True  trt_cp       72      D1  0.0743  0.4087  0.2991
# id_000a6266a      True  trt_cp       48      D1  0.6280  0.5817  1.5540
# id_0015fd391      True  trt_cp       48      D1 -0.5138 -0.2491 -0.2656
# id_001626bd3      True  trt_cp       72      D2 -0.3254 -0.4009  0.9700
# ...                ...     ...      ...     ...     ...     ...     ...
# id_ff7004b87     False  trt_cp       24      D1  0.4571 -0.5743  3.3930
# id_ff925dd0d     False  trt_cp       24      D1 -0.5885 -0.2548  2.5850
# id_ffb710450     False  trt_cp       72      D1 -0.3985 -0.1554  0.2677
# id_ffbb869f2     False  trt_cp       48      D2 -1.0960 -1.7750 -0.3977
# id_ffd5800b6     False  trt_cp       72      D1 -0.5174  0.2953  0.3286
#
#                  g-3     g-4     g-5  ...  \
# sig_id                                ...
# id_000644bb2 -0.6208 -0.1944 -1.0120  ...
# id_000779bfc  0.0604  1.0190  0.5207  ...
# id_000a6266a -0.0764 -0.0323  1.2390  ...
# id_0015fd391  0.5288  4.0620 -0.8095  ...
# id_001626bd3  0.6919  1.4180 -0.8244  ...
# ...              ...     ...     ...  ...
# id_ff7004b87 -0.6202  0.8557  1.6240  ...
# id_ff925dd0d  0.3456  0.4401  0.3107  ...
# id_ffb710450 -0.6813  0.0152  0.4791  ...
# id_ffbb869f2  1.0160 -1.3350 -0.2207  ...
# id_ffd5800b6 -0.0428 -0.0800  0.8702  ...
#
#               vesicular_monoamine_transporter_inhibitor  vitamin_k_antagonist  \
# sig_id
# id_000644bb2                                        0.0                   0.0
# id_000779bfc                                        0.0                   0.0
# id_000a6266a                                        0.0                   0.0
# id_0015fd391                                        0.0                   0.0
# id_001626bd3                                        0.0                   0.0
# ...                                                 ...                   ...
# id_ff7004b87                                        NaN                   NaN
# id_ff925dd0d                                        NaN                   NaN
# id_ffb710450                                        NaN                   NaN
# id_ffbb869f2                                        NaN                   NaN
# id_ffd5800b6                                        NaN                   NaN
#
#               voltage-gated_calcium_channel_ligand  \
# sig_id
# id_000644bb2                                   0.0
# id_000779bfc                                   0.0
# id_000a6266a                                   0.0
# id_0015fd391                                   0.0
# id_001626bd3                                   0.0
# ...                                            ...
# id_ff7004b87                                   NaN
# id_ff925dd0d                                   NaN
# id_ffb710450                                   NaN
# id_ffbb869f2                                   NaN
# id_ffd5800b6                                   NaN
#
#               voltage-gated_potassium_channel_activator  \
# sig_id
# id_000644bb2                                        0.0
# id_000779bfc                                        0.0
# id_000a6266a                                        0.0
# id_0015fd391                                        0.0
# id_001626bd3                                        0.0
# ...                                                 ...
# id_ff7004b87                                        NaN
# id_ff925dd0d                                        NaN
# id_ffb710450                                        NaN
# id_ffbb869f2                                        NaN
# id_ffd5800b6                                        NaN
#
#               voltage-gated_sodium_channel_blocker  \
# sig_id
# id_000644bb2                                   0.0
# id_000779bfc                                   0.0
# id_000a6266a                                   0.0
# id_0015fd391                                   0.0
# id_001626bd3                                   0.0
# ...                                            ...
# id_ff7004b87                                   NaN
# id_ff925dd0d                                   NaN
# id_ffb710450                                   NaN
# id_ffbb869f2                                   NaN
# id_ffd5800b6                                   NaN
#
#               wdr5_mll_interaction_inhibitor  wnt_agonist  \
# sig_id
# id_000644bb2                             0.0          0.0
# id_000779bfc                             0.0          0.0
# id_000a6266a                             0.0          0.0
# id_0015fd391                             0.0          0.0
# id_001626bd3                             0.0          0.0
# ...                                      ...          ...
# id_ff7004b87                             NaN          NaN
# id_ff925dd0d                             NaN          NaN
# id_ffb710450                             NaN          NaN
# id_ffbb869f2                             NaN          NaN
# id_ffd5800b6                             NaN          NaN
#
#               xanthine_oxidase_inhibitor  xiap_inhibitor    drug_id
# sig_id
# id_000644bb2                         0.0             0.0  b68db1d53
# id_000779bfc                         0.0             0.0  df89a8e5a
# id_000a6266a                         0.0             0.0  18bb41b2c
# id_0015fd391                         0.0             0.0  8c7f86626
# id_001626bd3                         0.0             0.0  7cbed3131
# ...                                  ...             ...        ...
# id_ff7004b87                         NaN             NaN        NaN
# id_ff925dd0d                         NaN             NaN        NaN
# id_ffb710450                         NaN             NaN        NaN
# id_ffbb869f2                         NaN             NaN        NaN
# id_ffd5800b6                         NaN             NaN        NaN
#
# [27796 rows x 1485 columns]

# %%
# Move column drug_id to positio 0 and add cell and gene names
df_dt = df_dataset.iloc[:, [-1] + list(range(0, len(df_dataset.columns)-1))].rename(columns={e[1]: e[0] for e in df_genes.values})
df_dt = df_dt.rename(columns={k: v for k, v in df_gene_mapping[['initial_alias', 'alias']].values})
df_dt = df_dt.rename(columns={k: v for k, v in df_cells[['new', 'alias']].values})
df_dt
# Out:
#                 drug_id  training cp_type  cp_time cp_dose  g-AARS1_16  \
# sig_id
# id_000644bb2  b68db1d53      True  trt_cp       24      D1      1.0620
# id_000779bfc  df89a8e5a      True  trt_cp       72      D1      0.0743
# id_000a6266a  18bb41b2c      True  trt_cp       48      D1      0.6280
# id_0015fd391  8c7f86626      True  trt_cp       48      D1     -0.5138
# id_001626bd3  7cbed3131      True  trt_cp       72      D2     -0.3254
# ...                 ...       ...     ...      ...     ...         ...
# id_ff7004b87        NaN     False  trt_cp       24      D1      0.4571
# id_ff925dd0d        NaN     False  trt_cp       24      D1     -0.5885
# id_ffb710450        NaN     False  trt_cp       72      D1     -0.3985
# id_ffbb869f2        NaN     False  trt_cp       48      D2     -1.0960
# id_ffd5800b6        NaN     False  trt_cp       72      D1     -0.5174
#
#               g-ABCF1_23  g-ABL1_25  g-ACAA1_30  g-ACLY_47  ...  \
# sig_id                                                      ...
# id_000644bb2      0.5577    -0.2479     -0.6208    -0.1944  ...
# id_000779bfc      0.4087     0.2991      0.0604     1.0190  ...
# id_000a6266a      0.5817     1.5540     -0.0764    -0.0323  ...
# id_0015fd391     -0.2491    -0.2656      0.5288     4.0620  ...
# id_001626bd3     -0.4009     0.9700      0.6919     1.4180  ...
# ...                  ...        ...         ...        ...  ...
# id_ff7004b87     -0.5743     3.3930     -0.6202     0.8557  ...
# id_ff925dd0d     -0.2548     2.5850      0.3456     0.4401  ...
# id_ffb710450     -0.1554     0.2677     -0.6813     0.0152  ...
# id_ffbb869f2     -1.7750    -0.3977      1.0160    -1.3350  ...
# id_ffd5800b6      0.2953     0.3286     -0.0428    -0.0800  ...
#
#               ve-cadherin_antagonist  \
# sig_id
# id_000644bb2                     0.0
# id_000779bfc                     0.0
# id_000a6266a                     0.0
# id_0015fd391                     0.0
# id_001626bd3                     0.0
# ...                              ...
# id_ff7004b87                     NaN
# id_ff925dd0d                     NaN
# id_ffb710450                     NaN
# id_ffbb869f2                     NaN
# id_ffd5800b6                     NaN
#
#               vesicular_monoamine_transporter_inhibitor  vitamin_k_antagonist  \
# sig_id
# id_000644bb2                                        0.0                   0.0
# id_000779bfc                                        0.0                   0.0
# id_000a6266a                                        0.0                   0.0
# id_0015fd391                                        0.0                   0.0
# id_001626bd3                                        0.0                   0.0
# ...                                                 ...                   ...
# id_ff7004b87                                        NaN                   NaN
# id_ff925dd0d                                        NaN                   NaN
# id_ffb710450                                        NaN                   NaN
# id_ffbb869f2                                        NaN                   NaN
# id_ffd5800b6                                        NaN                   NaN
#
#               voltage-gated_calcium_channel_ligand  \
# sig_id
# id_000644bb2                                   0.0
# id_000779bfc                                   0.0
# id_000a6266a                                   0.0
# id_0015fd391                                   0.0
# id_001626bd3                                   0.0
# ...                                            ...
# id_ff7004b87                                   NaN
# id_ff925dd0d                                   NaN
# id_ffb710450                                   NaN
# id_ffbb869f2                                   NaN
# id_ffd5800b6                                   NaN
#
#               voltage-gated_potassium_channel_activator  \
# sig_id
# id_000644bb2                                        0.0
# id_000779bfc                                        0.0
# id_000a6266a                                        0.0
# id_0015fd391                                        0.0
# id_001626bd3                                        0.0
# ...                                                 ...
# id_ff7004b87                                        NaN
# id_ff925dd0d                                        NaN
# id_ffb710450                                        NaN
# id_ffbb869f2                                        NaN
# id_ffd5800b6                                        NaN
#
#               voltage-gated_sodium_channel_blocker  \
# sig_id
# id_000644bb2                                   0.0
# id_000779bfc                                   0.0
# id_000a6266a                                   0.0
# id_0015fd391                                   0.0
# id_001626bd3                                   0.0
# ...                                            ...
# id_ff7004b87                                   NaN
# id_ff925dd0d                                   NaN
# id_ffb710450                                   NaN
# id_ffbb869f2                                   NaN
# id_ffd5800b6                                   NaN
#
#               wdr5_mll_interaction_inhibitor  wnt_agonist  \
# sig_id
# id_000644bb2                             0.0          0.0
# id_000779bfc                             0.0          0.0
# id_000a6266a                             0.0          0.0
# id_0015fd391                             0.0          0.0
# id_001626bd3                             0.0          0.0
# ...                                      ...          ...
# id_ff7004b87                             NaN          NaN
# id_ff925dd0d                             NaN          NaN
# id_ffb710450                             NaN          NaN
# id_ffbb869f2                             NaN          NaN
# id_ffd5800b6                             NaN          NaN
#
#               xanthine_oxidase_inhibitor  xiap_inhibitor
# sig_id
# id_000644bb2                         0.0             0.0
# id_000779bfc                         0.0             0.0
# id_000a6266a                         0.0             0.0
# id_0015fd391                         0.0             0.0
# id_001626bd3                         0.0             0.0
# ...                                  ...             ...
# id_ff7004b87                         NaN             NaN
# id_ff925dd0d                         NaN             NaN
# id_ffb710450                         NaN             NaN
# id_ffbb869f2                         NaN             NaN
# id_ffd5800b6                         NaN             NaN
#
# [27796 rows x 1485 columns]

# %%
df_dt.to_csv('lish_moa_annotated.csv.zip', compression='zip')
